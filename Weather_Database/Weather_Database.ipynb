# %% [markdown]
# ##  Deliverable 1: Retrieve Weather Data.

# %%
# Import the dependencies.
import pandas as pd
import sys
sys.path.append("/Users/jane.mathew/Desktop")
from api_keys import weather_api_key
import numpy as np
from citipy import citipy
import requests
import time
from datetime import datetime

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
     # Add 1 to the record count.
    record_count += 1
    
    
    # Run an API request for each of the cities.
    try:
         # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_current_description})
        
    # If an error is experienced, skip the city.
    except KeyError:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 1 | victoria
# Processing Record 3 of Set 1 | rawson
# Processing Record 4 of Set 1 | madaba
# Processing Record 5 of Set 1 | talnakh
# Processing Record 6 of Set 1 | mount gambier
# Processing Record 7 of Set 1 | tijuana
# Processing Record 8 of Set 1 | mar del plata
# Processing Record 9 of Set 1 | chokwe
# Processing Record 10 of Set 1 | batagay-alyta
# Processing Record 11 of Set 1 | ponta do sol
# Processing Record 12 of Set 1 | wurzburg
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | bayanday
# Processing Record 15 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | yurty
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | balvi
# Processing Record 22 of Set 1 | bonthe
# Processing Record 23 of Set 1 | taft
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | moron
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | tasiilaq
# Processing Record 28 of Set 1 | saldanha
# Processing Record 29 of Set 1 | bar harbor
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | kavieng
# Processing Record 33 of Set 1 | tiksi
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | butaritari
# Processing Record 38 of Set 1 | newport
# Processing Record 39 of Set 1 | bethel
# Processing Record 40 of Set 1 | meiganga
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | yanam
# Processing Record 43 of Set 1 | kaitangata
# Processing Record 44 of Set 1 | tuy hoa
# Processing Record 45 of Set 1 | carnarvon
# Processing Record 46 of Set 1 | boden
# Processing Record 47 of Set 1 | hasaki
# Processing Record 48 of Set 1 | santa isabel
# Processing Record 49 of Set 1 | moosomin
# Processing Record 50 of Set 1 | torbay
# Processing Record 1 of Set 2 | beringovskiy
# Processing Record 2 of Set 2 | khatanga
# Processing Record 3 of Set 2 | pacific grove
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 6 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 2 | rikitea
# Processing Record 8 of Set 2 | lorengau
# Processing Record 9 of Set 2 | lewisporte
# Processing Record 10 of Set 2 | grand gaube
# Processing Record 11 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | new norfolk
# Processing Record 14 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 2 | carinhanha
# Processing Record 17 of Set 2 | georgetown
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | port elizabeth
# Processing Record 20 of Set 2 | bontang
# Processing Record 21 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 2 | nikolskoye
# Processing Record 23 of Set 2 | bredasdorp
# Processing Record 24 of Set 2 | abu dhabi
# Processing Record 25 of Set 2 | lavrentiya
# Processing Record 26 of Set 2 | umm kaddadah
# Processing Record 27 of Set 2 | chokurdakh
# Processing Record 28 of Set 2 | glyadyanskoye
# Processing Record 29 of Set 2 | mugur-aksy
# Processing Record 30 of Set 2 | port alfred
# Processing Record 31 of Set 2 | east london
# Processing Record 32 of Set 2 | nkoteng
# Processing Record 33 of Set 2 | ilulissat
# Processing Record 34 of Set 2 | creel
# Processing Record 35 of Set 2 | nabire
# Processing Record 36 of Set 2 | shache
# Processing Record 37 of Set 2 | ambulu
# Processing Record 38 of Set 2 | mayumba
# Processing Record 39 of Set 2 | lebu
# Processing Record 40 of Set 2 | dinar
# Processing Record 41 of Set 2 | nizwa
# Processing Record 42 of Set 2 | hobyo
# Processing Record 43 of Set 2 | trinidad
# Processing Record 44 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 2 | rohru
# Processing Record 46 of Set 2 | narsaq
# Processing Record 47 of Set 2 | cabo san lucas
# Processing Record 48 of Set 2 | prijepolje
# Processing Record 49 of Set 2 | kasongo-lunda
# Processing Record 50 of Set 2 | hithadhoo
# Processing Record 1 of Set 3 | hilo
# Processing Record 2 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 3 | padang
# Processing Record 4 of Set 3 | mahibadhoo
# Processing Record 5 of Set 3 | pafos
# Processing Record 6 of Set 3 | talara
# Processing Record 7 of Set 3 | guangyuan
# Processing Record 8 of Set 3 | wadi musa
# Processing Record 9 of Set 3 | namibe
# Processing Record 10 of Set 3 | leh
# Processing Record 11 of Set 3 | saint george
# Processing Record 12 of Set 3 | puerto ayora
# Processing Record 13 of Set 3 | kutum
# Processing Record 14 of Set 3 | baillif
# Processing Record 15 of Set 3 | dingle
# Processing Record 16 of Set 3 | ribeira grande
# Processing Record 17 of Set 3 | souillac
# Processing Record 18 of Set 3 | paola
# Processing Record 19 of Set 3 | airai
# Processing Record 20 of Set 3 | medicine hat
# Processing Record 21 of Set 3 | neepawa
# Processing Record 22 of Set 3 | satipo
# Processing Record 23 of Set 3 | saskylakh
# Processing Record 24 of Set 3 | miresu mare
# Processing Record 25 of Set 3 | kristiinankaupunki
# Processing Record 26 of Set 3 | klaksvik
# Processing Record 27 of Set 3 | roebourne
# Processing Record 28 of Set 3 | caorle
# Processing Record 29 of Set 3 | douentza
# Processing Record 30 of Set 3 | roald
# Processing Record 31 of Set 3 | rimbey
# Processing Record 32 of Set 3 | nouakchott
# Processing Record 33 of Set 3 | prata
# Processing Record 34 of Set 3 | dehloran
# Processing Record 35 of Set 3 | northam
# Processing Record 36 of Set 3 | ostrovnoy
# Processing Record 37 of Set 3 | bubaque
# Processing Record 38 of Set 3 | korla
# Processing Record 39 of Set 3 | port lincoln
# Processing Record 40 of Set 3 | bintulu
# Processing Record 41 of Set 3 | ossora
# Processing Record 42 of Set 3 | dufftown
# Processing Record 43 of Set 3 | wanning
# Processing Record 44 of Set 3 | san jose
# Processing Record 45 of Set 3 | iqaluit
# Processing Record 46 of Set 3 | salalah
# Processing Record 47 of Set 3 | bambous virieux
# Processing Record 48 of Set 3 | tecoanapa
# Processing Record 49 of Set 3 | pevek
# Processing Record 50 of Set 3 | redlands
# Processing Record 1 of Set 4 | chuy
# Processing Record 2 of Set 4 | vila franca do campo
# Processing Record 3 of Set 4 | kuching
# Processing Record 4 of Set 4 | constitucion
# Processing Record 5 of Set 4 | sitka
# Processing Record 6 of Set 4 | antalaha
# Processing Record 7 of Set 4 | nanning
# Processing Record 8 of Set 4 | fortuna
# Processing Record 9 of Set 4 | chabahar
# Processing Record 10 of Set 4 | menongue
# Processing Record 11 of Set 4 | dikson
# Processing Record 12 of Set 4 | mahebourg
# Processing Record 13 of Set 4 | guiratinga
# Processing Record 14 of Set 4 | silyanah
# City not found. Skipping...
# Processing Record 15 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 4 | sola
# Processing Record 17 of Set 4 | xapuri
# Processing Record 18 of Set 4 | pangnirtung
# Processing Record 19 of Set 4 | esperance
# Processing Record 20 of Set 4 | san patricio
# Processing Record 21 of Set 4 | clyde river
# Processing Record 22 of Set 4 | linhai
# Processing Record 23 of Set 4 | bacolod
# Processing Record 24 of Set 4 | perth
# Processing Record 25 of Set 4 | san cristobal
# Processing Record 26 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 4 | progreso
# Processing Record 28 of Set 4 | katsuura
# Processing Record 29 of Set 4 | asau
# Processing Record 30 of Set 4 | grand baie
# Processing Record 31 of Set 4 | portland
# Processing Record 32 of Set 4 | castro
# Processing Record 33 of Set 4 | chicama
# Processing Record 34 of Set 4 | dugda
# Processing Record 35 of Set 4 | saint-philippe
# Processing Record 36 of Set 4 | ponta delgada
# Processing Record 37 of Set 4 | lasa
# Processing Record 38 of Set 4 | novoorsk
# Processing Record 39 of Set 4 | abnub
# Processing Record 40 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 4 | belyy yar
# Processing Record 42 of Set 4 | nokha
# Processing Record 43 of Set 4 | nuuk
# Processing Record 44 of Set 4 | pisco
# Processing Record 45 of Set 4 | goundam
# Processing Record 46 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 4 | gemena
# Processing Record 48 of Set 4 | labuhan
# Processing Record 49 of Set 4 | wahiawa
# Processing Record 50 of Set 4 | lompoc
# Processing Record 1 of Set 5 | kalininaul
# Processing Record 2 of Set 5 | arraial do cabo
# Processing Record 3 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 4 of Set 5 | aklavik
# Processing Record 5 of Set 5 | berdigestyakh
# Processing Record 6 of Set 5 | half moon bay
# Processing Record 7 of Set 5 | eldikan
# City not found. Skipping...
# Processing Record 8 of Set 5 | dudinka
# Processing Record 9 of Set 5 | ust-maya
# Processing Record 10 of Set 5 | el dorado
# Processing Record 11 of Set 5 | jumla
# Processing Record 12 of Set 5 | upernavik
# Processing Record 13 of Set 5 | port macquarie
# Processing Record 14 of Set 5 | tual
# Processing Record 15 of Set 5 | richards bay
# Processing Record 16 of Set 5 | bereznik
# Processing Record 17 of Set 5 | fairbanks
# Processing Record 18 of Set 5 | shakhrinau
# City not found. Skipping...
# Processing Record 19 of Set 5 | kulu
# Processing Record 20 of Set 5 | vestmannaeyjar
# Processing Record 21 of Set 5 | asayita
# City not found. Skipping...
# Processing Record 22 of Set 5 | honiara
# Processing Record 23 of Set 5 | platteville
# Processing Record 24 of Set 5 | uk
# City not found. Skipping...
# Processing Record 25 of Set 5 | tinskoy
# Processing Record 26 of Set 5 | victor harbor
# Processing Record 27 of Set 5 | puerto carreno
# Processing Record 28 of Set 5 | tuktoyaktuk
# Processing Record 29 of Set 5 | saint anthony
# Processing Record 30 of Set 5 | kapaa
# Processing Record 31 of Set 5 | barrow
# Processing Record 32 of Set 5 | pitea
# Processing Record 33 of Set 5 | puerto escondido
# Processing Record 34 of Set 5 | vila velha
# Processing Record 35 of Set 5 | oranjestad
# Processing Record 36 of Set 5 | cidreira
# Processing Record 37 of Set 5 | la tuque
# Processing Record 38 of Set 5 | popondetta
# Processing Record 39 of Set 5 | dois vizinhos
# Processing Record 40 of Set 5 | haines junction
# Processing Record 41 of Set 5 | katangli
# Processing Record 42 of Set 5 | hualmay
# Processing Record 43 of Set 5 | ust-ishim
# Processing Record 44 of Set 5 | raul soares
# Processing Record 45 of Set 5 | longyearbyen
# Processing Record 46 of Set 5 | touros
# Processing Record 47 of Set 5 | nome
# Processing Record 48 of Set 5 | isetskoye
# Processing Record 49 of Set 5 | orlik
# Processing Record 50 of Set 5 | tame
# Processing Record 1 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 2 of Set 6 | nanortalik
# Processing Record 3 of Set 6 | koslan
# Processing Record 4 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 6 | eureka
# Processing Record 6 of Set 6 | thompson
# Processing Record 7 of Set 6 | maracacume
# Processing Record 8 of Set 6 | harindanga
# Processing Record 9 of Set 6 | ahipara
# Processing Record 10 of Set 6 | okha
# Processing Record 11 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 12 of Set 6 | buenos aires
# Processing Record 13 of Set 6 | severo-kurilsk
# Processing Record 14 of Set 6 | port blair
# Processing Record 15 of Set 6 | kiunga
# Processing Record 16 of Set 6 | barretos
# Processing Record 17 of Set 6 | atuona
# Processing Record 18 of Set 6 | luderitz
# Processing Record 19 of Set 6 | yaan
# Processing Record 20 of Set 6 | jarjis
# City not found. Skipping...
# Processing Record 21 of Set 6 | cao bang
# Processing Record 22 of Set 6 | lagoa
# Processing Record 23 of Set 6 | afanasyevo
# City not found. Skipping...
# Processing Record 24 of Set 6 | kekri
# Processing Record 25 of Set 6 | olafsvik
# Processing Record 26 of Set 6 | srednekolymsk
# Processing Record 27 of Set 6 | eirunepe
# Processing Record 28 of Set 6 | geraldton
# Processing Record 29 of Set 6 | guanare
# Processing Record 30 of Set 6 | tessalit
# Processing Record 31 of Set 6 | walvis bay
# Processing Record 32 of Set 6 | boende
# Processing Record 33 of Set 6 | sal rei
# Processing Record 34 of Set 6 | alekseyevsk
# Processing Record 35 of Set 6 | maunabo
# Processing Record 36 of Set 6 | la ronge
# Processing Record 37 of Set 6 | santiago del estero
# Processing Record 38 of Set 6 | novaci
# Processing Record 39 of Set 6 | tashara
# Processing Record 40 of Set 6 | jaypur
# Processing Record 41 of Set 6 | valparaiso
# Processing Record 42 of Set 6 | provideniya
# Processing Record 43 of Set 6 | grand-santi
# Processing Record 44 of Set 6 | stephenville
# Processing Record 45 of Set 6 | haimen
# Processing Record 46 of Set 6 | requena
# Processing Record 47 of Set 6 | zhuhai
# Processing Record 48 of Set 6 | cam ranh
# Processing Record 49 of Set 6 | san angelo
# Processing Record 50 of Set 6 | ambrolauri
# Processing Record 1 of Set 7 | katherine
# Processing Record 2 of Set 7 | sao filipe
# Processing Record 3 of Set 7 | biskamzha
# Processing Record 4 of Set 7 | ocos
# Processing Record 5 of Set 7 | takestan
# Processing Record 6 of Set 7 | dicabisagan
# Processing Record 7 of Set 7 | westport
# Processing Record 8 of Set 7 | keuruu
# Processing Record 9 of Set 7 | alice springs
# Processing Record 10 of Set 7 | hami
# Processing Record 11 of Set 7 | chino valley
# Processing Record 12 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 13 of Set 7 | verkhnevilyuysk
# Processing Record 14 of Set 7 | gambela
# Processing Record 15 of Set 7 | mehamn
# Processing Record 16 of Set 7 | los llanos de aridane
# Processing Record 17 of Set 7 | ancud
# Processing Record 18 of Set 7 | san quintin
# Processing Record 19 of Set 7 | pemangkat
# Processing Record 20 of Set 7 | merauke
# Processing Record 21 of Set 7 | svetlogorsk
# Processing Record 22 of Set 7 | bagaha
# Processing Record 23 of Set 7 | vostok
# Processing Record 24 of Set 7 | champerico
# Processing Record 25 of Set 7 | banda aceh
# Processing Record 26 of Set 7 | codrington
# Processing Record 27 of Set 7 | kyshtovka
# Processing Record 28 of Set 7 | wote
# Processing Record 29 of Set 7 | waipawa
# Processing Record 30 of Set 7 | faya
# Processing Record 31 of Set 7 | akyab
# Processing Record 32 of Set 7 | margate
# Processing Record 33 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 7 | bima
# Processing Record 35 of Set 7 | sandwick
# Processing Record 36 of Set 7 | kavaratti
# Processing Record 37 of Set 7 | nara
# Processing Record 38 of Set 7 | fairhope
# Processing Record 39 of Set 7 | hofn
# Processing Record 40 of Set 7 | paita
# Processing Record 41 of Set 7 | norman wells
# Processing Record 42 of Set 7 | singapore
# Processing Record 43 of Set 7 | san ignacio
# Processing Record 44 of Set 7 | alofi
# Processing Record 45 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 7 | addi ugri
# City not found. Skipping...
# Processing Record 47 of Set 7 | grindavik
# Processing Record 48 of Set 7 | rocha
# Processing Record 49 of Set 7 | changying
# Processing Record 50 of Set 7 | christchurch
# Processing Record 1 of Set 8 | gilgit
# Processing Record 2 of Set 8 | blind river
# Processing Record 3 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 8 | flinders
# Processing Record 5 of Set 8 | shenjiamen
# Processing Record 6 of Set 8 | dieppe bay
# City not found. Skipping...
# Processing Record 7 of Set 8 | kahului
# Processing Record 8 of Set 8 | narasannapeta
# Processing Record 9 of Set 8 | truckee
# Processing Record 10 of Set 8 | kodiak
# Processing Record 11 of Set 8 | chiradzulu
# Processing Record 12 of Set 8 | aswan
# Processing Record 13 of Set 8 | poum
# Processing Record 14 of Set 8 | saint-joseph
# Processing Record 15 of Set 8 | mackay
# Processing Record 16 of Set 8 | tilichiki
# Processing Record 17 of Set 8 | nioki
# Processing Record 18 of Set 8 | carauari
# Processing Record 19 of Set 8 | bollene
# Processing Record 20 of Set 8 | wilmington
# Processing Record 21 of Set 8 | houma
# Processing Record 22 of Set 8 | vanimo
# Processing Record 23 of Set 8 | cherskiy
# Processing Record 24 of Set 8 | jutai
# Processing Record 25 of Set 8 | mehkar
# Processing Record 26 of Set 8 | tortoli
# Processing Record 27 of Set 8 | lokosovo
# Processing Record 28 of Set 8 | karasjok
# Processing Record 29 of Set 8 | mackenzie
# Processing Record 30 of Set 8 | tukrah
# Processing Record 31 of Set 8 | guerrero negro
# Processing Record 32 of Set 8 | qaqortoq
# Processing Record 33 of Set 8 | bazarnyye mataki
# Processing Record 34 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 35 of Set 8 | mastic beach
# Processing Record 36 of Set 8 | robertsport
# Processing Record 37 of Set 8 | vila
# Processing Record 38 of Set 8 | jalu
# Processing Record 39 of Set 8 | shirdi
# Processing Record 40 of Set 8 | meulaboh
# Processing Record 41 of Set 8 | berlevag
# Processing Record 42 of Set 8 | tecolutla
# Processing Record 43 of Set 8 | le pradet
# Processing Record 44 of Set 8 | liberty
# Processing Record 45 of Set 8 | coihaique
# Processing Record 46 of Set 8 | asmar
# Processing Record 47 of Set 8 | port hardy
# Processing Record 48 of Set 8 | lgov
# Processing Record 49 of Set 8 | anadyr
# Processing Record 50 of Set 8 | coquimbo
# Processing Record 1 of Set 9 | amahai
# Processing Record 2 of Set 9 | saint-georges
# Processing Record 3 of Set 9 | te anau
# Processing Record 4 of Set 9 | bay roberts
# Processing Record 5 of Set 9 | astana
# Processing Record 6 of Set 9 | harwich
# Processing Record 7 of Set 9 | road town
# Processing Record 8 of Set 9 | la palma
# Processing Record 9 of Set 9 | havelock
# Processing Record 10 of Set 9 | bozoum
# Processing Record 11 of Set 9 | bayan
# Processing Record 12 of Set 9 | husavik
# Processing Record 13 of Set 9 | qui nhon
# Processing Record 14 of Set 9 | kautokeino
# Processing Record 15 of Set 9 | bengkulu
# Processing Record 16 of Set 9 | pitimbu
# Processing Record 17 of Set 9 | banjar
# Processing Record 18 of Set 9 | shirokiy
# Processing Record 19 of Set 9 | karratha
# Processing Record 20 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 9 | teya
# Processing Record 22 of Set 9 | vao
# Processing Record 23 of Set 9 | imeni poliny osipenko
# Processing Record 24 of Set 9 | yatou
# Processing Record 25 of Set 9 | bud
# Processing Record 26 of Set 9 | yumbe
# Processing Record 27 of Set 9 | naze
# Processing Record 28 of Set 9 | innisfail
# Processing Record 29 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 9 | itarema
# Processing Record 31 of Set 9 | francisco sa
# Processing Record 32 of Set 9 | turbat
# Processing Record 33 of Set 9 | sulangan
# Processing Record 34 of Set 9 | san juan
# Processing Record 35 of Set 9 | bam
# Processing Record 36 of Set 9 | samarai
# Processing Record 37 of Set 9 | sumenep
# Processing Record 38 of Set 9 | dixon
# Processing Record 39 of Set 9 | ulaangom
# Processing Record 40 of Set 9 | kuandian
# Processing Record 41 of Set 9 | ihosy
# Processing Record 42 of Set 9 | kargopol
# Processing Record 43 of Set 9 | saint-pierre
# Processing Record 44 of Set 9 | nyurba
# Processing Record 45 of Set 9 | whitehorse
# Processing Record 46 of Set 9 | manokwari
# Processing Record 47 of Set 9 | san andres
# Processing Record 48 of Set 9 | dawei
# Processing Record 49 of Set 9 | havoysund
# Processing Record 50 of Set 9 | bulgan
# Processing Record 1 of Set 10 | gigmoto
# Processing Record 2 of Set 10 | bratunac
# Processing Record 3 of Set 10 | gaya
# Processing Record 4 of Set 10 | salinopolis
# Processing Record 5 of Set 10 | da nang
# Processing Record 6 of Set 10 | marsa matruh
# Processing Record 7 of Set 10 | juba
# Processing Record 8 of Set 10 | nha trang
# Processing Record 9 of Set 10 | maarianhamina
# Processing Record 10 of Set 10 | brownsburg
# Processing Record 11 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 12 of Set 10 | lumphat
# Processing Record 13 of Set 10 | santiago
# Processing Record 14 of Set 10 | coahuayana
# Processing Record 15 of Set 10 | cascas
# Processing Record 16 of Set 10 | kathu
# Processing Record 17 of Set 10 | huarmey
# Processing Record 18 of Set 10 | ternate
# Processing Record 19 of Set 10 | renukut
# Processing Record 20 of Set 10 | ugoofaaru
# Processing Record 21 of Set 10 | bonavista
# Processing Record 22 of Set 10 | faanui
# Processing Record 23 of Set 10 | anisoc
# Processing Record 24 of Set 10 | karauli
# Processing Record 25 of Set 10 | arkhara
# Processing Record 26 of Set 10 | phuthaditjhaba
# Processing Record 27 of Set 10 | huejuquilla el alto
# Processing Record 28 of Set 10 | hoquiam
# Processing Record 29 of Set 10 | cockburn town
# Processing Record 30 of Set 10 | atka
# City not found. Skipping...
# Processing Record 31 of Set 10 | aksu
# Processing Record 32 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 10 | hamilton
# Processing Record 34 of Set 10 | vilyuysk
# Processing Record 35 of Set 10 | itapirapua
# Processing Record 36 of Set 10 | gloversville
# Processing Record 37 of Set 10 | manggar
# Processing Record 38 of Set 10 | baijiantan
# Processing Record 39 of Set 10 | moroto
# Processing Record 40 of Set 10 | ust-tsilma
# Processing Record 41 of Set 10 | ambilobe
# Processing Record 42 of Set 10 | vuktyl
# Processing Record 43 of Set 10 | kirakira
# Processing Record 44 of Set 10 | tuatapere
# Processing Record 45 of Set 10 | abha
# Processing Record 46 of Set 10 | nantucket
# Processing Record 47 of Set 10 | dovers
# Processing Record 48 of Set 10 | andenes
# Processing Record 49 of Set 10 | vangaindrano
# Processing Record 50 of Set 10 | bana
# Processing Record 1 of Set 11 | hervey bay
# Processing Record 2 of Set 11 | neuquen
# Processing Record 3 of Set 11 | sandviken
# Processing Record 4 of Set 11 | kencong
# Processing Record 5 of Set 11 | ouesso
# Processing Record 6 of Set 11 | sakakah
# Processing Record 7 of Set 11 | kununurra
# Processing Record 8 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 11 | verkhoyansk
# Processing Record 10 of Set 11 | muravlenko
# Processing Record 11 of Set 11 | abonnema
# Processing Record 12 of Set 11 | santa marta
# Processing Record 13 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 14 of Set 11 | lyantonde
# Processing Record 15 of Set 11 | senno
# Processing Record 16 of Set 11 | muros
# Processing Record 17 of Set 11 | sobolevo
# Processing Record 18 of Set 11 | marsh harbour
# Processing Record 19 of Set 11 | broken hill
# Processing Record 20 of Set 11 | manzil jamil
# City not found. Skipping...
# Processing Record 21 of Set 11 | myitkyina
# Processing Record 22 of Set 11 | kibre mengist
# Processing Record 23 of Set 11 | takoradi
# Processing Record 24 of Set 11 | erzurum
# Processing Record 25 of Set 11 | dole
# Processing Record 26 of Set 11 | burnie
# Processing Record 27 of Set 11 | pachino
# Processing Record 28 of Set 11 | malacky
# Processing Record 29 of Set 11 | bowen
# Processing Record 30 of Set 11 | mbandaka
# Processing Record 31 of Set 11 | ballina
# Processing Record 32 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 33 of Set 11 | harrisburg
# Processing Record 34 of Set 11 | quatre cocos
# Processing Record 35 of Set 11 | port hawkesbury
# Processing Record 36 of Set 11 | keningau
# Processing Record 37 of Set 11 | hakvik
# City not found. Skipping...
# Processing Record 38 of Set 11 | mao
# Processing Record 39 of Set 11 | thunder bay
# Processing Record 40 of Set 11 | kieta
# Processing Record 41 of Set 11 | long beach
# Processing Record 42 of Set 11 | thinadhoo
# Processing Record 43 of Set 11 | aguadilla
# Processing Record 44 of Set 11 | gweru
# Processing Record 45 of Set 11 | mount isa
# Processing Record 46 of Set 11 | barcelos
# Processing Record 47 of Set 11 | chacabuco
# Processing Record 48 of Set 11 | addis zemen
# City not found. Skipping...
# Processing Record 49 of Set 11 | aqtobe
# Processing Record 50 of Set 11 | jawhar
# Processing Record 1 of Set 12 | terra santa
# Processing Record 2 of Set 12 | uni
# Processing Record 3 of Set 12 | manavalakurichi
# Processing Record 4 of Set 12 | asfi
# Processing Record 5 of Set 12 | gorontalo
# Processing Record 6 of Set 12 | timra
# Processing Record 7 of Set 12 | savannah bight
# Processing Record 8 of Set 12 | hanko
# Processing Record 9 of Set 12 | tiarei
# Processing Record 10 of Set 12 | one hundred mile house
# City not found. Skipping...
# Processing Record 11 of Set 12 | nagua
# Processing Record 12 of Set 12 | bathsheba
# Processing Record 13 of Set 12 | whyalla
# Processing Record 14 of Set 12 | mildura
# Processing Record 15 of Set 12 | osakarovka
# Processing Record 16 of Set 12 | galesong
# Processing Record 17 of Set 12 | aban
# Processing Record 18 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 19 of Set 12 | broome
# Processing Record 20 of Set 12 | maputo
# Processing Record 21 of Set 12 | tigil
# Processing Record 22 of Set 12 | sandakan
# Processing Record 23 of Set 12 | rancho grande
# Processing Record 24 of Set 12 | algeciras
# Processing Record 25 of Set 12 | san carlos de bariloche
# Processing Record 26 of Set 12 | caninde
# Processing Record 27 of Set 12 | doha
# Processing Record 28 of Set 12 | volnovakha
# Processing Record 29 of Set 12 | inta
# Processing Record 30 of Set 12 | ravar
# Processing Record 31 of Set 12 | hanzhong
# Processing Record 32 of Set 12 | chibombo
# Processing Record 33 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 12 | susangerd
# Processing Record 35 of Set 12 | enkhuizen
# Processing Record 36 of Set 12 | norden
# Processing Record 37 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 38 of Set 12 | porto novo
# Processing Record 39 of Set 12 | port hedland
# Processing Record 40 of Set 12 | boa viagem
# Processing Record 41 of Set 12 | necochea
# Processing Record 42 of Set 12 | chapada dos guimaraes
# Processing Record 43 of Set 12 | batagay
# Processing Record 44 of Set 12 | acapulco
# Processing Record 45 of Set 12 | plettenberg bay
# Processing Record 46 of Set 12 | riyadh
# Processing Record 47 of Set 12 | waingapu
# Processing Record 48 of Set 12 | salto
# Processing Record 49 of Set 12 | boguchany
# Processing Record 50 of Set 12 | kruisfontein
# Processing Record 1 of Set 13 | botro
# Processing Record 2 of Set 13 | laguna
# Processing Record 3 of Set 13 | neustadt
# Processing Record 4 of Set 13 | maragheh
# Processing Record 5 of Set 13 | la paz
# Processing Record 6 of Set 13 | kangaatsiaq
# Processing Record 7 of Set 13 | altay
# Processing Record 8 of Set 13 | boysun
# Processing Record 9 of Set 13 | san juan del rio
# Processing Record 10 of Set 13 | bandar
# Processing Record 11 of Set 13 | lazaro cardenas
# Processing Record 12 of Set 13 | avera
# Processing Record 13 of Set 13 | joensuu
# Processing Record 14 of Set 13 | lincoln
# Processing Record 15 of Set 13 | ovalle
# Processing Record 16 of Set 13 | leningradskiy
# Processing Record 17 of Set 13 | geilo
# Processing Record 18 of Set 13 | nampula
# Processing Record 19 of Set 13 | camopi
# Processing Record 20 of Set 13 | bethanien
# Processing Record 21 of Set 13 | daru
# Processing Record 22 of Set 13 | porto belo
# Processing Record 23 of Set 13 | mansa
# Processing Record 24 of Set 13 | moroni
# Processing Record 25 of Set 13 | la gaulette
# City not found. Skipping...
# Processing Record 26 of Set 13 | axim
# Processing Record 27 of Set 13 | callaway
# Processing Record 28 of Set 13 | ina
# Processing Record 29 of Set 13 | praia da vitoria
# Processing Record 30 of Set 13 | vardo
# Processing Record 31 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 32 of Set 13 | alyangula
# Processing Record 33 of Set 13 | katobu
# Processing Record 34 of Set 13 | santa maria
# Processing Record 35 of Set 13 | cayenne
# Processing Record 36 of Set 13 | whitehaven
# Processing Record 37 of Set 13 | yertsevo
# Processing Record 38 of Set 13 | teahupoo
# Processing Record 39 of Set 13 | tarapur
# Processing Record 40 of Set 13 | stromness
# Processing Record 41 of Set 13 | sinnamary
# Processing Record 42 of Set 13 | tavricheskoye
# Processing Record 43 of Set 13 | mutare
# Processing Record 44 of Set 13 | santa isabel do rio negro
# Processing Record 45 of Set 13 | goure
# Processing Record 46 of Set 13 | sorong
# Processing Record 47 of Set 13 | muli
# Processing Record 48 of Set 13 | concepcion
# Processing Record 49 of Set 13 | emerald
# Processing Record 50 of Set 13 | kabo
# Processing Record 1 of Set 14 | gari
# Processing Record 2 of Set 14 | kloulklubed
# Processing Record 3 of Set 14 | erenhot
# Processing Record 4 of Set 14 | grand island
# Processing Record 5 of Set 14 | conceicao do araguaia
# Processing Record 6 of Set 14 | ibirapitanga
# Processing Record 7 of Set 14 | monrovia
# Processing Record 8 of Set 14 | emmett
# Processing Record 9 of Set 14 | ust-nera
# Processing Record 10 of Set 14 | pushchino
# Processing Record 11 of Set 14 | ust-katav
# Processing Record 12 of Set 14 | salta
# Processing Record 13 of Set 14 | itabirito
# Processing Record 14 of Set 14 | mazamari
# Processing Record 15 of Set 14 | viana
# Processing Record 16 of Set 14 | melfi
# Processing Record 17 of Set 14 | oktyabrskiy
# Processing Record 18 of Set 14 | oksfjord
# Processing Record 19 of Set 14 | uwayl
# City not found. Skipping...
# Processing Record 20 of Set 14 | bosaso
# Processing Record 21 of Set 14 | dzerzhinskoye
# Processing Record 22 of Set 14 | buraydah
# Processing Record 23 of Set 14 | qinhuangdao
# Processing Record 24 of Set 14 | terenos
# Processing Record 25 of Set 14 | governador valadares
# Processing Record 26 of Set 14 | noumea
# Processing Record 27 of Set 14 | pundaguitan
# Processing Record 28 of Set 14 | methoni
# Processing Record 29 of Set 14 | jiaojiang
# Processing Record 30 of Set 14 | goderich
# Processing Record 31 of Set 14 | ajdabiya
# Processing Record 32 of Set 14 | erseke
# Processing Record 33 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 34 of Set 14 | calbuco
# Processing Record 35 of Set 14 | baghdad
# Processing Record 36 of Set 14 | labrea
# Processing Record 37 of Set 14 | cherkasskoye
# Processing Record 38 of Set 14 | west springfield
# Processing Record 39 of Set 14 | sao joao da barra
# Processing Record 40 of Set 14 | lukulu
# Processing Record 41 of Set 14 | erhlin
# City not found. Skipping...
# Processing Record 42 of Set 14 | tecpan
# Processing Record 43 of Set 14 | ahwa
# Processing Record 44 of Set 14 | la romana
# Processing Record 45 of Set 14 | samarkand
# Processing Record 46 of Set 14 | garmsar
# Processing Record 47 of Set 14 | camabatela
# Processing Record 48 of Set 14 | mpika
# Processing Record 49 of Set 14 | andrews
# Processing Record 50 of Set 14 | maumere
# Processing Record 1 of Set 15 | surt
# Processing Record 2 of Set 15 | racine
# Processing Record 3 of Set 15 | luena
# Processing Record 4 of Set 15 | ushtobe
# Processing Record 5 of Set 15 | mancio lima
# Processing Record 6 of Set 15 | krasnoselkup
# Processing Record 7 of Set 15 | impfondo
# Processing Record 8 of Set 15 | misratah
# Processing Record 9 of Set 15 | andra
# Processing Record 10 of Set 15 | paciran
# Processing Record 11 of Set 15 | charters towers
# Processing Record 12 of Set 15 | gamba
# Processing Record 13 of Set 15 | aleksandrovsk-sakhalinskiy
# Processing Record 14 of Set 15 | ingham
# Processing Record 15 of Set 15 | gornopravdinsk
# Processing Record 16 of Set 15 | sinjar
# Processing Record 17 of Set 15 | sao miguel
# Processing Record 18 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 15 | sri aman
# Processing Record 20 of Set 15 | aykhal
# Processing Record 21 of Set 15 | nioro
# Processing Record 22 of Set 15 | alihe
# Processing Record 23 of Set 15 | taunggyi
# Processing Record 24 of Set 15 | oranjemund
# Processing Record 25 of Set 15 | lakes entrance
# Processing Record 26 of Set 15 | shchuchye
# City not found. Skipping...
# Processing Record 27 of Set 15 | umm lajj
# Processing Record 28 of Set 15 | north bend
# Processing Record 29 of Set 15 | gondanglegi
# Processing Record 30 of Set 15 | namatanai
# Processing Record 31 of Set 15 | macaubas
# Processing Record 32 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 34 of Set 15 | inhambane
# Processing Record 35 of Set 15 | dunedin
# Processing Record 36 of Set 15 | palana
# Processing Record 37 of Set 15 | santa fe
# Processing Record 38 of Set 15 | talaya
# Processing Record 39 of Set 15 | andros town
# Processing Record 40 of Set 15 | yashkul
# Processing Record 41 of Set 15 | kaberamaido
# Processing Record 42 of Set 15 | tanout
# Processing Record 43 of Set 15 | zhigansk
# Processing Record 44 of Set 15 | lake city
# Processing Record 45 of Set 15 | badarpur
# Processing Record 46 of Set 15 | belyye berega
# Processing Record 47 of Set 15 | mahajanga
# Processing Record 48 of Set 15 | aripuana
# Processing Record 49 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 50 of Set 15 | udachnyy
# Processing Record 1 of Set 16 | altamira
# Processing Record 2 of Set 16 | shuyskoye
# Processing Record 3 of Set 16 | dhidhdhoo
# Processing Record 4 of Set 16 | ornskoldsvik
# Processing Record 5 of Set 16 | khasan
# Processing Record 6 of Set 16 | sioux lookout
# Processing Record 7 of Set 16 | aranos
# Processing Record 8 of Set 16 | calais
# Processing Record 9 of Set 16 | algiers
# Processing Record 10 of Set 16 | bowmore
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Victoria  22.2855  114.1577     65.25        83          57
# 1         Rawson -43.3002  -65.1023     66.16        57          12
# 2         Madaba  31.5833   35.6667     48.88        59          59
# 3        Talnakh  69.4865   88.3972     -5.80        97         100
# 4  Mount Gambier -37.8333  140.7667     76.64        42          47
# 5        Tijuana  32.5333 -117.0167     74.75        46          20
# 6  Mar Del Plata -38.0023  -57.5575     74.08        43           0
# 7         Chokwe -24.5333   32.9833     69.87        93           0
# 8  Batagay-Alyta  67.8006  130.4114    -21.96        87          53
# 9   Ponta Do Sol  32.6667  -17.1000     66.70        51          99
#
#    Wind Speed Country                 Date Current Description
# 0        1.01      HK  2022-01-10 00:15:25       broken clouds
# 1       10.47      AR  2022-01-10 00:18:03          few clouds
# 2        6.38      JO  2022-01-10 00:18:03       broken clouds
# 3        3.22      RU  2022-01-10 00:18:04          light snow
# 4        7.20      AU  2022-01-10 00:18:05    scattered clouds
# 5       10.36      MX  2022-01-10 00:15:31          few clouds
# 6        5.99      AR  2022-01-10 00:18:06           clear sky
# 7        4.61      MZ  2022-01-10 00:18:07           clear sky
# 8        3.87      RU  2022-01-10 00:18:07       broken clouds
# 9        9.66      PT  2022-01-10 00:18:08     overcast clouds

# %%
# Reorder column headers
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Victoria      HK  22.2855  114.1577     65.25        83          57
# 1           Rawson      AR -43.3002  -65.1023     66.16        57          12
# 2           Madaba      JO  31.5833   35.6667     48.88        59          59
# 3          Talnakh      RU  69.4865   88.3972     -5.80        97         100
# 4    Mount Gambier      AU -37.8333  140.7667     76.64        42          47
# ..             ...     ...      ...       ...       ...       ...         ...
# 697  Sioux Lookout      CA  50.1001  -91.9170    -14.42        70          20
# 698         Aranos      NA -24.1333   19.1167     72.32        68          87
# 699         Calais      FR  50.9167    1.8333     36.05        77           6
# 700        Algiers      DZ  36.7525    3.0420     53.42        58          20
# 701        Bowmore      US  34.9421  -79.3031     66.04        63         100
#
#      Wind Speed Current Description
# 0          1.01       broken clouds
# 1         10.47          few clouds
# 2          6.38       broken clouds
# 3          3.22          light snow
# 4          7.20    scattered clouds
# ..          ...                 ...
# 697        8.05          few clouds
# 698        8.14     overcast clouds
# 699        1.43           clear sky
# 700       12.66          few clouds
# 701       13.80     overcast clouds
#
# [702 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
